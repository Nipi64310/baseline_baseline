# %%
import pandas as pd
import numpy as np
import time

# %%
ac = pd.read_csv('data/trainset/action_train.csv')
order = pd.read_csv('data/trainset/orderFuture_train.csv')
order_his = pd.read_csv('data/trainset/orderHistory_train.csv')
comment = pd.read_csv('data/trainset/userComment_train.csv')
profile = pd.read_csv('data/trainset/userProfile_train.csv')

ac_test = pd.read_csv('data/test/action_test.csv')
order_test = pd.read_csv('data/test/orderFuture_test.csv')
order_his_test = pd.read_csv('data/test/orderHistory_test.csv')
comment_test = pd.read_csv('data/test/userComment_test.csv')
profile_test = pd.read_csv('data/test/userProfile_test.csv')

# %%
# 用户id，行为类型，发生时间
# 行为类型一共有9个，其中1是唤醒app；2~4是浏览产品，无先后关系；5~9则是有先后关系的，从填写表单到提交订单再到最后支付
ac.head()
# Out:
#          userid  actionType  actionTime
# 0  100000000013           1  1474300753
# 1  100000000013           5  1474300763
# 2  100000000013           6  1474300874
# 3  100000000013           5  1474300911
# 4  100000000013           6  1474300936

# %%
order.head()
#两列，分别是用户id和订单类型。供参赛者训练模型使用。其中1表示购买了精品旅游服务，0表示未购买精品旅游服务（包括普通旅游服务和未下订单）

# 预测订单类型
# Out:
#          userid  orderType
# 0  100000000013          0
# 1  100000000111          0
# 2  100000000127          0
# 3  100000000231          0
# 4  100000000379          0

# %%
comment.head(5)
# Out:
#          userid  orderid  rating                   tags     commentsKeyWords
# 0  100000000013  1000015     4.0                    NaN  ['很','简陋','太','随便']
# 1  100000000231  1000024     5.0              提前联系|耐心等候           ['很','细心']
# 2  100000000471  1000038     5.0                    NaN                  NaN
# 3  100000000637  1000040     5.0  主动热情|提前联系|举牌迎接|主动搬运行李                  NaN
# 4  100000000755  1000045     1.0                  未举牌服务                  NaN

# %%
order_his.head()
# 数据共有7列，分别是用户id，订单id，订单时间，订单类型，旅游城市，国家，大陆。其中1表示购买了精品旅游服务，0表示普通旅游服务。
# Out:
#          userid  orderid   orderTime  orderType city country continent
# 0  100000000013  1000015  1481714516          0   柏林      德国        欧洲
# 1  100000000013  1000014  1501959643          0  旧金山      美国       北美洲
# 2  100000000393  1000033  1499440296          0   巴黎      法国        欧洲
# 3  100000000459  1000036  1480601668          0   纽约      美国       北美洲
# 4  100000000459  1000034  1479146723          0  巴厘岛   印度尼西亚        亚洲

# %%
profile.head()
# 数据共有四列，分别是用户id、性别、省份、年龄段
# Out:
#          userid gender province  age
# 0  100000000013      男      NaN  60后
# 1  100000000111    NaN       上海  NaN
# 2  100000000127    NaN       上海  NaN
# 3  100000000231      男       北京  70后
# 4  100000000379      男       北京  NaN

# %%
timeArray = time.localtime(1474300753)
time.strftime('%Y-%m-%d %H:%M:%S', timeArray)
# Out:
# '2016-09-19 23:59:13'

# %%
order[order.userid == 100000000231]
# Out:
#          userid  orderType
# 3  100000000231          0

# %%
comment.commentsKeyWords.head(20)
# Out:
# 0                               ['很','简陋','太','随便']
# 1                                        ['很','细心']
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6            ['真心','好','惊喜','惊喜','合理','还','真心','赞']
# 7                                               NaN
# 8     ['非常','满意','认真','负责','诚恳','合理','很','精致','希望']
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                  ['very','good']
# 14                                              NaN
# 15                              ['很','负责','辛苦','还']
# 16        ['非常','好','还','好','还','很','热情','美丽','肯定']
# 17                                      ['非常','满意']
# 18                                              NaN
# 19                                              NaN
# Name: commentsKeyWords, dtype: object

# %%
def time_help(x):
    timeArray = time.localtime(x)
    return time.strftime('%Y-%m-%d %H:%M:%S', timeArray)
    
ac.actionTime = pd.to_datetime(ac.actionTime.apply(lambda x:time_help(x)), format='%Y-%m-%d %H:%M:%S')
order_his.orderTime = pd.to_datetime(order_his.orderTime.apply(lambda x:time_help(x)), format='%Y-%m-%d %H:%M:%S')
ac_test.actionTime = pd.to_datetime(ac_test.actionTime.apply(lambda x:time_help(x)), format='%Y-%m-%d %H:%M:%S')
order_his_test.orderTime = pd.to_datetime(order_his_test.orderTime.apply(lambda x:time_help(x)), format='%Y-%m-%d %H:%M:%S')

# %%
ac.head()
# Out:
#          userid  actionType          actionTime
# 0  100000000013           1 2016-09-19 23:59:13
# 1  100000000013           5 2016-09-19 23:59:23
# 2  100000000013           6 2016-09-20 00:01:14
# 3  100000000013           5 2016-09-20 00:01:51
# 4  100000000013           6 2016-09-20 00:02:16

# %%
# t = ac.actionTime.iloc[1]
ac['day'] = ac.actionTime.apply(lambda x:x.day)
ac_test['day'] = ac_test.actionTime.apply(lambda x:x.day)

# %%
# print(t.year, t.month, t.day, t.second, t.minute,t.hour)

# %%
# ac['count'] = 1
# ac[['userid', 'actionType']].groupby('userid', as_index=False).agg('last')

# %%
# ac[(ac.userid == 100000000459) && (ac.actionT)]

# %%
# order[order.userid == 100000000459]
# order['count'] = 1
# order[['userid', 'count']].groupby('userid', as_index=False).agg('count')
# del order['count']

# ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg('last')
# ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg('first')

# ac.actionTime.
# ac = pd.read_csv('data/trainset/action_train.csv')
# ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg('last')
# ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg('mean')

# order_his[['userid', 'orderType']].groupby('userid', as_index=False).agg('max')

# order  对应 userid,  所在  order_his的 最后一个 的 城市

# order_his.head()
# order_his.drop_duplicates(subset='userid', keep='last')
# order_his[[order_his[['userid']].drop_duplicates(keep='last').index]]
# pd.merge(order_his[['userid']].drop_duplicates(keep='last'), order_his, on='userid', how='left')

# %% [markdown]
# feature
# 1. order  的 actionType 的最后一个
#   ac
# 2. 时间间隔的第1个值和最后一个值
#   ac  actiontime
# 3. 之前 是否定过精品，flag

# %%
# len(order_his_test.city.unique())

# %%
##user过去是否订购过orderType    以及比率
def orderHistory_feat(df):
    grouped=df[['userid','orderType']].groupby('userid',as_index=False)
    df_count=grouped.count()
    df_count.rename(columns={'orderType':'df_count'},inplace=True)
    df_sum=grouped.sum()
    
    df_sum.rename(columns={'orderType':'df_sum'},inplace=True)
    df_merge=pd.merge(df_count,df_sum,on='userid',how='left')
    df_merge['rate']=df_merge['df_sum']/df_merge['df_count']
    del df_merge['df_count']
    df_merge.rename(columns={'df_sum':'orderHistory_feat_sum','rate':'orderHistory_feat_rate'},inplace=True)
    
    # rate  的 score 很低
    del df_merge['orderHistory_feat_rate']
    return df_merge

# 点击比率
def actions_orderType(df):
    df['count']=1
    df_count=df[['userid','count']].groupby('userid',as_index=False).count()
    actionType=pd.get_dummies(df['actionType'],prefix='actionType')
    df=pd.concat([df['userid'],actionType],axis=1)
    df=df.groupby('userid',as_index=False).sum()
    for column in range(1,df.shape[1]):
        df['actionType_{}'.format(column)]=df['actionType_{}'.format(column)]/df_count['count']
    return df


def get_two(arr):
    try:
        tem = int(arr.iloc[-2])
        return tem
    except:
        return np.nan

def get_three(arr):
    try:
        tem = int(arr.iloc[-3])
        return tem
    except:
        return np.nan

# order 的 actionType 的最后一个 行为， 倒数第二个， 倒数第三个
def last_action (df):
    last_type = df[['userid', 'actionType']].groupby('userid', as_index=False).agg('last')
    last_type.rename(columns={'actionType':'last_type'}, inplace=True)
    
    two_type = df[['userid', 'actionType']].groupby('userid', as_index=False).agg(get_two)
    two_type.rename(columns={'actionType':'two_type'}, inplace=True)
    
    three_type = df[['userid', 'actionType']].groupby('userid', as_index=False).agg(get_three)
    three_type.rename(columns={'actionType':'three_type'}, inplace=True)
    two_type
    
    last = pd.merge(last_type, two_type, on='userid', how='left')
    last = pd.merge(last, three_type, on='userid', how='left')
    
    return last
    

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# order所在城市
def last_city(train, test):
    city = list(order_his['city'].unique())
    city_test = list(order_his_test['city'].unique())
    for i in city_test:
        if i not in city:
            city.append(i)
    le.fit(city)
    
    new = order_his[['userid', 'city', 'continent']].drop_duplicates(subset='userid', keep='last')
    new['city'] = le.transform(new['city'])
   
    new_test = order_his_test[['userid', 'city', 'continent']].drop_duplicates(subset='userid', keep='last')
    new_test['city'] = le.transform(new_test['city']) 
    
    new['continent'] = le.fit_transform(new['continent'])
    new_test['continent'] = le.transform(new_test['continent'])
    
    train = pd.merge(train, new, on='userid', how='left')
    test = pd.merge(test, new_test, on='userid', how='left')
    return train, test


def profile_me(train, test):
    
    for i in ['province', 'gender', 'age']:
        train[i] = train[i].factorize()[0]
        test[i] = test[i].factorize()[0]
        
        train[i] = le.fit_transform(train[i])
        test[i] = le.transform(test[i])
    
    return train, test


def fun1(arr):
#     print(arr.iloc[-1], arr.iloc[-2])
    try:
        return ((arr.iloc[-1]) - (arr.iloc[-2])).seconds
    except:
        return np.nan

def fun2(arr):
    try:
        return ((arr.iloc[-1]) - (arr.iloc[-2])).days
    except:
        return np.nan

def fun3(arr):
    try:
        return ((arr.iloc[-2]) - (arr.iloc[-3])).days
    except:
        return np.nan

def fun4(arr):
    try:
        return ((arr.iloc[-2]) - (arr.iloc[-3])).seconds
    except:
        return np.nan
        
# ac 倒数第一次和 倒数第二次， 倒数第三次的间隔时间
def ac_time(train, test):

    las_two_day = ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun2)
    las_two_day.rename(columns={'actionTime':'last_two_day'}, inplace=True)
    las_two_second = ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun1)
    las_two_second.rename(columns={'actionTime':'last_two_second'}, inplace=True)
    
    two_three_day = ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun3)
    two_three_day.rename(columns={'actionTime':'two_three_day'}, inplace=True)
    two_three_second = ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun4)
    two_three_second.rename(columns={'actionTime':'two_three_second'}, inplace=True)
    
#         time_mean = ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun3)
#         time_mean.rename(columns={'actionTime':'time_mean'}, inplace=True)
#         time_std = ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun4)
#         time_std.rename(columns={'actionTime':'time_std'}, inplace=True)

    train = pd.merge(train, las_two_day, on='userid', how='left')
    train = pd.merge(train, las_two_second, on='userid', how='left')
    train = pd.merge(train, two_three_day, on='userid', how='left')
    train = pd.merge(train, two_three_second, on='userid', how='left')

    las_two_day_ = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun2)
    las_two_day_.rename(columns={'actionTime':'last_two_day'}, inplace=True)
    las_two_second_ = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun1)
    las_two_second_.rename(columns={'actionTime':'last_two_second'}, inplace=True)
    
    two_three_day = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun3)
    two_three_day.rename(columns={'actionTime':'two_three_day'}, inplace=True)
    two_three_second = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun4)
    two_three_second.rename(columns={'actionTime':'two_three_second'}, inplace=True)
    
#         time_std = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun4)
#         time_std.rename(columns={'actionTime':'time_std'}, inplace=True)


    test = pd.merge(test, las_two_day_, on='userid', how='left')
    test = pd.merge(test, las_two_second_, on='userid', how='left')
    test = pd.merge(test, two_three_day, on='userid', how='left')
    test = pd.merge(test, two_three_second, on='userid', how='left')

    return train, test

# comment rating
# def ratting_score()

def fun5(timeseries):
# 时间间隔的均值
    sum = []
    for i in range(len(timeseries) - 1):
        sum.append((timeseries.iloc[i+ 1] - timeseries.iloc[i]).seconds)
    return np.mean(sum)

def fun6(timeseries):
# 时间间隔的均值
    sum = []
    for i in range(len(timeseries) - 1):
        sum.append((timeseries.iloc[i+1] - timeseries.iloc[i]).seconds)
    return np.std(sum)

def time_delta(train, test):
    time_mean = ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun5)
    time_mean.rename(columns={'actionTime':'timedelta_mean'}, inplace=True)
    time_std = ac[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun5)
    time_std.rename(columns={'actionTime':'timedelta_std'}, inplace=True)
    
    train = pd.merge(train, time_mean, on='userid', how='left')
    train = pd.merge(train, time_std, on='userid', how='left')
    
    time_mean = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun5)
    time_mean.rename(columns={'actionTime':'timedelta_mean'}, inplace=True)
    time_std = ac_test[['userid', 'actionTime']].groupby('userid', as_index=False).agg(fun6)
    time_std.rename(columns={'actionTime':'timedelta_std'}, inplace=True)
    
    test = pd.merge(test, time_mean, on='userid', how='left')
    test = pd.merge(test, time_std, on='userid', how='left')
    return train, test

# 历史最后一次时间对应action中点击的什么, 组合
def his_s(train, test):
    df = order_his.drop_duplicates(subset='userid', keep='last').reset_index(drop=True)
    last_type = []
    for i in range(len(df)):
        temp_time = df.loc[i, 'orderTime']
        temp_id = df.loc[i, 'userid']
        new = ac[ac.userid == temp_id]
        new = new[new.actionTime < temp_time]
        if(len(new) != 0):
            new = new.iloc[-1]
            last_type.append(new.actionType)
        else:
            last_type.append(np.nan)
    last_type = pd.Series(np.array(last_type))
    last_type.index = df.index
    last_type = pd.DataFrame(last_type, columns=['hist_type'])
    last_type['userid'] = df['userid']
    train = pd.merge(train, last_type, on='userid', how='left')
    
    df = order_his_test.drop_duplicates(subset='userid', keep='last').reset_index(drop=True)
    last_type = []
    for i in range(len(df)):
        temp_time = df.loc[i, 'orderTime']
        temp_id = df.loc[i, 'userid']
        new = ac_test[ac_test.userid == temp_id]
        new = new[new.actionTime < temp_time]
        if(len(new) != 0):
            new = new.iloc[-1]
            last_type.append(new.actionType)
        else:
            last_type.append(np.nan)
    last_type = pd.Series(np.array(last_type))
    last_type.index = df.index
    last_type = pd.DataFrame(last_type, columns=['hist_type'])
    last_type['userid'] = df['userid']
    
    test = pd.merge(test, last_type, on='userid', how='left')
    return train, test


# def fun7(type)

# 距离 最近的 5, 6 , 7 , 8的 seconds
def distance_last(odf, a=5):
    name = 'flag_'+ str(a)
    odf[name] = (odf.actionType == a) * 1
    
    id = []
    dis = []
    for i in list(odf.userid.unique()):
        id.append(i)
        
        df = odf[odf.userid == i]
        time1 = df.actionTime.iloc[-1]
        
        df = df[df[name] == 1]
        if (len(df) != 0):
            if df.iloc[-1].actionTime == time1:
                df = df[:-1]
            if len(df) >= 1:
                dis.append((time1 - df.iloc[-1].actionTime).seconds)
            else:
                dis.append(np.nan)
        else:
            dis.append(np.nan)
    column_name = 'last_' + str(a) + 'dis'
    new_df = pd.DataFrame({'userid':id,
                           column_name:dis})
    return new_df
    
        
    

# 最后操作那一天 action 的count
def action_count(train, test):
    count = []
    id = []
    for i in (ac.userid.unique()):
        id.append(i)
        df = ac[ac.userid == i]
        df = df.loc[df.day == df.iloc[-1].day]
        count.append(len(df))
    new = pd.DataFrame({'userid':id, 
                       'count':count})
    train = pd.merge(train, new, on='userid', how='left')
    
    count = []
    id = []
    for i in (ac_test.userid.unique()):
        id.append(i)
        df = ac_test[ac_test.userid == i]
        df = df.loc[df.day == df.iloc[-1].day]
        count.append(len(df))
    new = pd.DataFrame({'userid':id, 
                       'count':count})
    test = pd.merge(test, new, on='userid', how='left')
    return train, test

# orderType
def flags_buy(df):
    flags = []
    id = []
    for i in list(df.userid.unique()):
        id.append(i)
        df_ = df[df.userid == i]
        if df_.orderType.sum() != 0:
            flags.append(1)
        else:
            flags.append(0)
    new = pd.DataFrame({
        'userid':id,
        'buy_flags':flags
    })
    return new

# %%
def gen_train_feat():
    actions = order
    actions_test = order_test
    
   
    actions = pd.merge(actions, distance_last(ac, 5), on='userid', how='left')
    actions_test = pd.merge(actions_test, distance_last(ac_test, 5), on='userid', how='left')
    
    actions = pd.merge(actions, distance_last(ac, 6), on='userid', how='left')
    actions_test = pd.merge(actions_test, distance_last(ac_test, 6), on='userid', how='left')
    
    actions = pd.merge(actions, distance_last(ac, 7), on='userid', how='left')
    actions_test = pd.merge(actions_test, distance_last(ac_test, 7), on='userid', how='left')
    
    actions = pd.merge(actions, distance_last(ac, 8), on='userid', how='left')
    actions_test = pd.merge(actions_test, distance_last(ac_test, 8), on='userid', how='left')
    
    actions = pd.merge(actions, distance_last(ac, 9), on='userid', how='left')
    actions_test = pd.merge(actions_test, distance_last(ac_test, 9), on='userid', how='left')
    actions, actions_test = action_count(actions, actions_test)
    actions = pd.merge(actions,orderHistory_feat(order_his),on='userid',how='left')
    actions = pd.merge(actions,actions_orderType(ac),on='userid',how='left')
    actions = pd.merge(actions,last_action(ac),on='userid',how='left')  
    
    actions_test = pd.merge(actions_test,orderHistory_feat(order_his_test),on='userid',how='left')
    actions_test = pd.merge(actions_test,actions_orderType(ac_test),on='userid',how='left')
    actions_test = pd.merge(actions_test,last_action(ac_test),on='userid',how='left')
    
    actions, actions_test = last_city(actions, actions_test)
    
    profile_, profile_test_ = profile_me(profile, profile_test)
    actions = pd.merge(actions, profile_, on='userid', how='left')
    actions_test = pd.merge(actions_test, profile_test_, on='userid', how='left')
    actions, actions_test = ac_time(actions, actions_test)
    
    actions = pd.merge(actions, comment[['userid', 'rating']], on='userid', how='left')
    actions_test = pd.merge(actions_test, comment_test[['userid', 'rating']], on='userid', how='left')
    
    actions['flag_five'] = (actions['last_type'] == 5) * 1
    actions['flag_six'] = (actions['last_type'] == 6) * 1
    actions['flag_seven'] = (actions['last_type'] == 1) * 1
    
    actions_test['flag_five'] = (actions_test['last_type'] == 5) * 1
    actions_test['flag_six'] = (actions_test['last_type'] == 6) * 1
    actions_test['flag_seven'] = (actions_test['last_type'] == 7) * 1
    
    
#     actions = pd.merge(actions, flags_buy(order_his), on='userid', how='left')
#     actions_test = pd.merge(actions_test, flags_buy(order_his_test), on='userid', how='left')
    
#     actions, actions_test = time_delta(actions, actions_test)

#     actions, actions_test = his_s(actions, actions_test)
    return actions, actions_test

# %%
# train_data.to_csv('data/checkpoint_train.csv', index=False)
# test_data.to_csv('data/checkpoint_test.csv', index=False)

# %%
order.rename(columns={'orderType':'label'},inplace=True)
train_data, test_data=gen_train_feat()
train_data.head()
# Out:
#          userid  label  buy_flags
# 0  100000000013      0        0.0
# 1  100000000111      0        NaN
# 2  100000000127      0        NaN
# 3  100000000231      0        NaN
# 4  100000000379      0        NaN

# %%
#c_train = pd.read_csv('data/checkpoint_train.csv')
#c_test = pd.read_csv('data/checkpoint_test.csv')
#del c_train['orderType']
#train_data = pd.merge(c_train, train_data, how='left', on='userid')
#test_data = pd.merge(c_test, test_data, how='left', on='userid')

# %%
from sklearn.model_selection import train_test_split
train_label=train_data['label']
del train_data['label']
x_train,x_val,y_train,y_val=train_test_split(train_data,train_label,test_size=0.2,random_state=100)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32245 entries, 5544 to 38408
# Data columns (total 34 columns):
# userid                   32245 non-null int64
# last_5dis                30476 non-null float64
# last_6dis                26282 non-null float64
# last_7dis                7203 non-null float64
# last_8dis                9526 non-null float64
# last_9dis                7135 non-null float64
# count                    32245 non-null int64
# orderHistory_feat_sum    8518 non-null float64
# actionType_1             32245 non-null float64
# actionType_2             32245 non-null float64
# actionType_3             32245 non-null float64
# actionType_4             32245 non-null float64
# actionType_5             32245 non-null float64
# actionType_6             32245 non-null float64
# actionType_7             32245 non-null float64
# actionType_8             32245 non-null float64
# actionType_9             32245 non-null float64
# last_type                32245 non-null int64
# two_type                 31240 non-null float64
# three_type               30649 non-null float64
# city                     8518 non-null float64
# continent                8518 non-null float64
# gender                   32245 non-null int64
# province                 32245 non-null int64
# age                      32245 non-null int64
# last_two_day             31240 non-null float64
# last_two_second          31240 non-null float64
# two_three_day            30649 non-null float64
# two_three_second         30649 non-null float64
# rating                   7857 non-null float64
# flag_five                32245 non-null int64
# flag_six                 32245 non-null int64
# flag_seven               32245 non-null int64
# buy_flags                8518 non-null float64
# dtypes: float64(25), int64(9)
# memory usage: 8.6 MB

# %%
# del test_data['orderType']
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10076 entries, 0 to 10075
# Data columns (total 34 columns):
# userid                   10076 non-null int64
# last_5dis                9501 non-null float64
# last_6dis                8200 non-null float64
# last_7dis                2252 non-null float64
# last_8dis                2995 non-null float64
# last_9dis                2219 non-null float64
# count                    10076 non-null int64
# orderHistory_feat_sum    2686 non-null float64
# actionType_1             10076 non-null float64
# actionType_2             10076 non-null float64
# actionType_3             10076 non-null float64
# actionType_4             10076 non-null float64
# actionType_5             10076 non-null float64
# actionType_6             10076 non-null float64
# actionType_7             10076 non-null float64
# actionType_8             10076 non-null float64
# actionType_9             10076 non-null float64
# last_type                10076 non-null int64
# two_type                 9722 non-null float64
# three_type               9544 non-null float64
# city                     2686 non-null float64
# continent                2686 non-null float64
# gender                   10076 non-null int64
# province                 10076 non-null int64
# age                      10076 non-null int64
# last_two_day             9722 non-null float64
# last_two_second          9722 non-null float64
# two_three_day            9544 non-null float64
# two_three_second         9544 non-null float64
# rating                   2474 non-null float64
# flag_five                10076 non-null int64
# flag_six                 10076 non-null int64
# flag_seven               10076 non-null int64
# buy_flags                2686 non-null float64
# dtypes: float64(25), int64(9)
# memory usage: 3.0 MB

# %%
# 调参失败， 电脑炸了

# %%
# del test_data['orderType']

# %%
import xgboost as xgb
print ('start running ....')
dtrain = xgb.DMatrix(x_train,label=y_train)
dval = xgb.DMatrix(x_val,label=y_val)
param = {'learning_rate' : 0.1,
        'n_estimators': 1000,
        'max_depth': 4,
        'min_child_weight': 7,
        'gamma': 0,
        'subsample': 0.94,
        'colsample_bytree': 0.75,
        'eta': 0.05,
        'silent': 1,
        'objective':
        'binary:logistic',
        'scale_pos_weight':1}

num_round =666
plst = list(param.items())
plst += [('eval_metric', 'auc')]
evallist = [(dval, 'eval'), (dtrain, 'train')]
bst=xgb.train(plst,dtrain,num_round,evallist,early_stopping_rounds=100)
dtest = xgb.DMatrix(test_data)
y = bst.predict(dtest)
# Out:
# start running ....
# [0]	eval-auc:0.819828	train-auc:0.816973
# Multiple eval metrics have been passed: 'train-auc' will be used for early stopping.
#
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	eval-auc:0.839604	train-auc:0.834355
# [2]	eval-auc:0.841011	train-auc:0.836347
# [3]	eval-auc:0.860001	train-auc:0.853497
# [4]	eval-auc:0.864739	train-auc:0.855608
# [5]	eval-auc:0.86561	train-auc:0.856885
# [6]	eval-auc:0.867917	train-auc:0.854782
# [7]	eval-auc:0.864301	train-auc:0.851976
# [8]	eval-auc:0.866368	train-auc:0.853649
# [9]	eval-auc:0.869583	train-auc:0.858388
# [10]	eval-auc:0.87903	train-auc:0.867452
# [11]	eval-auc:0.87965	train-auc:0.866644
# [12]	eval-auc:0.878375	train-auc:0.866654
# [13]	eval-auc:0.881434	train-auc:0.871081
# [14]	eval-auc:0.883573	train-auc:0.87275
# [15]	eval-auc:0.885187	train-auc:0.874749
# [16]	eval-auc:0.887769	train-auc:0.876837
# [17]	eval-auc:0.887781	train-auc:0.877328
# [18]	eval-auc:0.889127	train-auc:0.879404
# [19]	eval-auc:0.893457	train-auc:0.88439
# [20]	eval-auc:0.893514	train-auc:0.885517
# [21]	eval-auc:0.894028	train-auc:0.885562
# [22]	eval-auc:0.894319	train-auc:0.885727
# [23]	eval-auc:0.89546	train-auc:0.886197
# [24]	eval-auc:0.899876	train-auc:0.890706
# [25]	eval-auc:0.902753	train-auc:0.894211
# [26]	eval-auc:0.903336	train-auc:0.894416
# [27]	eval-auc:0.905964	train-auc:0.896551
# [28]	eval-auc:0.906908	train-auc:0.897596
# [29]	eval-auc:0.908534	train-auc:0.899164
# [30]	eval-auc:0.912367	train-auc:0.903208
# [31]	eval-auc:0.913663	train-auc:0.904624
# [32]	eval-auc:0.914441	train-auc:0.906165
# [33]	eval-auc:0.915232	train-auc:0.907098
# [34]	eval-auc:0.917216	train-auc:0.90935
# [35]	eval-auc:0.918015	train-auc:0.910373
# [36]	eval-auc:0.918441	train-auc:0.911273
# [37]	eval-auc:0.91969	train-auc:0.913049
# [38]	eval-auc:0.920284	train-auc:0.913662
# [39]	eval-auc:0.920878	train-auc:0.914277
# [40]	eval-auc:0.921708	train-auc:0.915138
# [41]	eval-auc:0.922781	train-auc:0.916155
# [42]	eval-auc:0.923299	train-auc:0.916803
# [43]	eval-auc:0.923826	train-auc:0.91747
# [44]	eval-auc:0.925395	train-auc:0.918893
# [45]	eval-auc:0.927166	train-auc:0.920836
# [46]	eval-auc:0.927484	train-auc:0.921465
# [47]	eval-auc:0.927641	train-auc:0.921795
# [48]	eval-auc:0.928315	train-auc:0.922977
# [49]	eval-auc:0.928963	train-auc:0.923631
# [50]	eval-auc:0.930242	train-auc:0.925062
# [51]	eval-auc:0.930658	train-auc:0.925624
# [52]	eval-auc:0.931054	train-auc:0.926115
# [53]	eval-auc:0.931308	train-auc:0.926495
# [54]	eval-auc:0.931621	train-auc:0.926932
# [55]	eval-auc:0.932616	train-auc:0.928273
# [56]	eval-auc:0.932853	train-auc:0.928523
# [57]	eval-auc:0.933266	train-auc:0.928977
# [58]	eval-auc:0.93389	train-auc:0.929506
# [59]	eval-auc:0.934074	train-auc:0.929825
# [60]	eval-auc:0.934311	train-auc:0.93018
# [61]	eval-auc:0.934563	train-auc:0.930606
# [62]	eval-auc:0.934852	train-auc:0.931013
# [63]	eval-auc:0.935053	train-auc:0.931219
# [64]	eval-auc:0.935403	train-auc:0.931859
# [65]	eval-auc:0.935893	train-auc:0.932426
# [66]	eval-auc:0.93623	train-auc:0.933032
# [67]	eval-auc:0.936585	train-auc:0.93365
# [68]	eval-auc:0.936958	train-auc:0.933922
# [69]	eval-auc:0.93705	train-auc:0.934009
# [70]	eval-auc:0.937169	train-auc:0.934423
# [71]	eval-auc:0.937211	train-auc:0.934535
# [72]	eval-auc:0.937354	train-auc:0.935063
# [73]	eval-auc:0.937432	train-auc:0.935314
# [74]	eval-auc:0.937674	train-auc:0.935643
# [75]	eval-auc:0.937978	train-auc:0.93596
# [76]	eval-auc:0.938131	train-auc:0.936264
# [77]	eval-auc:0.938329	train-auc:0.93655
# [78]	eval-auc:0.938424	train-auc:0.936675
# [79]	eval-auc:0.93864	train-auc:0.936951
# [80]	eval-auc:0.93908	train-auc:0.937369
# [81]	eval-auc:0.939355	train-auc:0.937577
# [82]	eval-auc:0.939513	train-auc:0.937748
# [83]	eval-auc:0.939604	train-auc:0.937882
# [84]	eval-auc:0.939663	train-auc:0.937977
# [85]	eval-auc:0.939649	train-auc:0.937974
# [86]	eval-auc:0.939801	train-auc:0.938248
# [87]	eval-auc:0.939937	train-auc:0.938405
# [88]	eval-auc:0.940056	train-auc:0.938664
# [89]	eval-auc:0.940306	train-auc:0.938912
# [90]	eval-auc:0.940391	train-auc:0.939045
# [91]	eval-auc:0.940753	train-auc:0.939354
# [92]	eval-auc:0.940981	train-auc:0.939822
# [93]	eval-auc:0.940811	train-auc:0.940089
# [94]	eval-auc:0.940945	train-auc:0.940244
# [95]	eval-auc:0.941077	train-auc:0.940343
# [96]	eval-auc:0.941121	train-auc:0.940415
# [97]	eval-auc:0.941296	train-auc:0.940836
# [98]	eval-auc:0.941408	train-auc:0.941164
# [99]	eval-auc:0.941522	train-auc:0.941353
# [100]	eval-auc:0.941675	train-auc:0.94165
# [101]	eval-auc:0.94185	train-auc:0.942008
# [102]	eval-auc:0.941809	train-auc:0.94222
# [103]	eval-auc:0.941881	train-auc:0.942343
# [104]	eval-auc:0.942582	train-auc:0.943093
# [105]	eval-auc:0.942628	train-auc:0.943148
# [106]	eval-auc:0.942683	train-auc:0.943208
# [107]	eval-auc:0.942845	train-auc:0.943577
# [108]	eval-auc:0.943009	train-auc:0.943753
# [109]	eval-auc:0.943138	train-auc:0.943928
# [110]	eval-auc:0.943113	train-auc:0.943963
# [111]	eval-auc:0.943244	train-auc:0.944138
# [112]	eval-auc:0.943194	train-auc:0.944357
# [113]	eval-auc:0.94335	train-auc:0.944588
# [114]	eval-auc:0.943437	train-auc:0.944807
# [115]	eval-auc:0.94349	train-auc:0.944934
# [116]	eval-auc:0.943499	train-auc:0.945012
# [117]	eval-auc:0.943598	train-auc:0.945109
# [118]	eval-auc:0.943595	train-auc:0.94521
# [119]	eval-auc:0.943653	train-auc:0.945265
# [120]	eval-auc:0.943962	train-auc:0.94565
# [121]	eval-auc:0.94407	train-auc:0.945818
# [122]	eval-auc:0.944029	train-auc:0.945956
# [123]	eval-auc:0.944009	train-auc:0.946035
# [124]	eval-auc:0.944573	train-auc:0.946546
# [125]	eval-auc:0.944602	train-auc:0.946679
# [126]	eval-auc:0.944923	train-auc:0.946949
# [127]	eval-auc:0.944953	train-auc:0.946995
# [128]	eval-auc:0.944908	train-auc:0.947031
# [129]	eval-auc:0.945104	train-auc:0.947325
# [130]	eval-auc:0.945115	train-auc:0.947411
# [131]	eval-auc:0.945151	train-auc:0.9476
# [132]	eval-auc:0.945215	train-auc:0.947631
# [133]	eval-auc:0.945252	train-auc:0.947791
# [134]	eval-auc:0.945234	train-auc:0.947981
# [135]	eval-auc:0.945313	train-auc:0.948128
# [136]	eval-auc:0.945253	train-auc:0.948243
# [137]	eval-auc:0.945407	train-auc:0.948423
# [138]	eval-auc:0.94547	train-auc:0.948556
# [139]	eval-auc:0.945807	train-auc:0.948982
# [140]	eval-auc:0.945801	train-auc:0.949111
# [141]	eval-auc:0.945983	train-auc:0.949394
# [142]	eval-auc:0.946011	train-auc:0.949493
# [143]	eval-auc:0.946	train-auc:0.94952
# [144]	eval-auc:0.946007	train-auc:0.949652
# [145]	eval-auc:0.945988	train-auc:0.949701
# [146]	eval-auc:0.946117	train-auc:0.949898
# [147]	eval-auc:0.946162	train-auc:0.950046
# [148]	eval-auc:0.946246	train-auc:0.950285
# [149]	eval-auc:0.946191	train-auc:0.950331
# [150]	eval-auc:0.94631	train-auc:0.950473
# [151]	eval-auc:0.946324	train-auc:0.950528
# [152]	eval-auc:0.946382	train-auc:0.95064
# [153]	eval-auc:0.946373	train-auc:0.950681
# [154]	eval-auc:0.94634	train-auc:0.950729
# [155]	eval-auc:0.946344	train-auc:0.950886
# [156]	eval-auc:0.946348	train-auc:0.951036
# [157]	eval-auc:0.946482	train-auc:0.951174
# [158]	eval-auc:0.946597	train-auc:0.9514
# [159]	eval-auc:0.946583	train-auc:0.951481
# [160]	eval-auc:0.94659	train-auc:0.951519
# [161]	eval-auc:0.946585	train-auc:0.951563
# [162]	eval-auc:0.946684	train-auc:0.951693
# [163]	eval-auc:0.946714	train-auc:0.951742
# [164]	eval-auc:0.946691	train-auc:0.95182
# [165]	eval-auc:0.946755	train-auc:0.951941
# [166]	eval-auc:0.946815	train-auc:0.952116
# [167]	eval-auc:0.946855	train-auc:0.95221
# [168]	eval-auc:0.946919	train-auc:0.952313
# [169]	eval-auc:0.946917	train-auc:0.952374
# [170]	eval-auc:0.947116	train-auc:0.95259
# [171]	eval-auc:0.947139	train-auc:0.952646
# [172]	eval-auc:0.947261	train-auc:0.952815
# [173]	eval-auc:0.947306	train-auc:0.952958
# [174]	eval-auc:0.947328	train-auc:0.953018
# [175]	eval-auc:0.947302	train-auc:0.953089
# [176]	eval-auc:0.947413	train-auc:0.953201
# [177]	eval-auc:0.947445	train-auc:0.953305
# [178]	eval-auc:0.947668	train-auc:0.95341
# [179]	eval-auc:0.947673	train-auc:0.953415
# [180]	eval-auc:0.947698	train-auc:0.953575
# [181]	eval-auc:0.947651	train-auc:0.953675
# [182]	eval-auc:0.94766	train-auc:0.953713
# [183]	eval-auc:0.947644	train-auc:0.953753
# [184]	eval-auc:0.947611	train-auc:0.953781
# [185]	eval-auc:0.947592	train-auc:0.953849
# [186]	eval-auc:0.947703	train-auc:0.953957
# [187]	eval-auc:0.947782	train-auc:0.954129
# [188]	eval-auc:0.94783	train-auc:0.954186
# [189]	eval-auc:0.94869	train-auc:0.95477
# [190]	eval-auc:0.948762	train-auc:0.954918
# [191]	eval-auc:0.948751	train-auc:0.954954
# [192]	eval-auc:0.948772	train-auc:0.955068
# [193]	eval-auc:0.948742	train-auc:0.955179
# [194]	eval-auc:0.948796	train-auc:0.955268
# [195]	eval-auc:0.948839	train-auc:0.95535
# [196]	eval-auc:0.948822	train-auc:0.955557
# [197]	eval-auc:0.948834	train-auc:0.955655
# [198]	eval-auc:0.949328	train-auc:0.955977
# [199]	eval-auc:0.949364	train-auc:0.956087
# [200]	eval-auc:0.949393	train-auc:0.956178
# [201]	eval-auc:0.949539	train-auc:0.956327
# [202]	eval-auc:0.949548	train-auc:0.956349
# [203]	eval-auc:0.949574	train-auc:0.956439
# [204]	eval-auc:0.949645	train-auc:0.95651
# [205]	eval-auc:0.949664	train-auc:0.956564
# [206]	eval-auc:0.949676	train-auc:0.956668
# [207]	eval-auc:0.949723	train-auc:0.956732
# [208]	eval-auc:0.949727	train-auc:0.956766
# [209]	eval-auc:0.949721	train-auc:0.956823
# [210]	eval-auc:0.949778	train-auc:0.956907
# [211]	eval-auc:0.949802	train-auc:0.956971
# [212]	eval-auc:0.949837	train-auc:0.957023
# [213]	eval-auc:0.949897	train-auc:0.957075
# [214]	eval-auc:0.949922	train-auc:0.957179
# [215]	eval-auc:0.949896	train-auc:0.957232
# [216]	eval-auc:0.950002	train-auc:0.957322
# [217]	eval-auc:0.950005	train-auc:0.957419
# [218]	eval-auc:0.95008	train-auc:0.957553
# [219]	eval-auc:0.950072	train-auc:0.957614
# [220]	eval-auc:0.950047	train-auc:0.957662
# [221]	eval-auc:0.95002	train-auc:0.957684
# [222]	eval-auc:0.950016	train-auc:0.95773
# [223]	eval-auc:0.95006	train-auc:0.957785
# [224]	eval-auc:0.950114	train-auc:0.95792
# [225]	eval-auc:0.95009	train-auc:0.95801
# [226]	eval-auc:0.950081	train-auc:0.958094
# [227]	eval-auc:0.95011	train-auc:0.958118
# [228]	eval-auc:0.950108	train-auc:0.958236
# [229]	eval-auc:0.950207	train-auc:0.958434
# [230]	eval-auc:0.950185	train-auc:0.958521
# [231]	eval-auc:0.950194	train-auc:0.95858
# [232]	eval-auc:0.950203	train-auc:0.958671
# [233]	eval-auc:0.950236	train-auc:0.958723
# [234]	eval-auc:0.950312	train-auc:0.958778
# [235]	eval-auc:0.950323	train-auc:0.958915
# [236]	eval-auc:0.950317	train-auc:0.958982
# [237]	eval-auc:0.950304	train-auc:0.959063
# [238]	eval-auc:0.950324	train-auc:0.959093
# [239]	eval-auc:0.950333	train-auc:0.959105
# [240]	eval-auc:0.950381	train-auc:0.959194
# [241]	eval-auc:0.950327	train-auc:0.959221
# [242]	eval-auc:0.950414	train-auc:0.959323
# [243]	eval-auc:0.950498	train-auc:0.959434
# [244]	eval-auc:0.950598	train-auc:0.959624
# [245]	eval-auc:0.950549	train-auc:0.959663
# [246]	eval-auc:0.950588	train-auc:0.959742
# [247]	eval-auc:0.950637	train-auc:0.959831
# [248]	eval-auc:0.950629	train-auc:0.959902
# [249]	eval-auc:0.950653	train-auc:0.959959
# [250]	eval-auc:0.95067	train-auc:0.960087
# [251]	eval-auc:0.950639	train-auc:0.960135
# [252]	eval-auc:0.950623	train-auc:0.960163
# [253]	eval-auc:0.950668	train-auc:0.960255
# [254]	eval-auc:0.950676	train-auc:0.96033
# [255]	eval-auc:0.950801	train-auc:0.960382
# [256]	eval-auc:0.950938	train-auc:0.96044
# [257]	eval-auc:0.951025	train-auc:0.960528
# [258]	eval-auc:0.951171	train-auc:0.960607
# [259]	eval-auc:0.951259	train-auc:0.960688
# [260]	eval-auc:0.951231	train-auc:0.960722
# [261]	eval-auc:0.951285	train-auc:0.960875
# [262]	eval-auc:0.951289	train-auc:0.960923
# [263]	eval-auc:0.951292	train-auc:0.960994
# [264]	eval-auc:0.951359	train-auc:0.96107
# [265]	eval-auc:0.951416	train-auc:0.961209
# [266]	eval-auc:0.951452	train-auc:0.961284
# [267]	eval-auc:0.951483	train-auc:0.961387
# [268]	eval-auc:0.951522	train-auc:0.961434
# [269]	eval-auc:0.951514	train-auc:0.961551
# [270]	eval-auc:0.951478	train-auc:0.961682
# [271]	eval-auc:0.951512	train-auc:0.961853
# [272]	eval-auc:0.951559	train-auc:0.961993
# [273]	eval-auc:0.95149	train-auc:0.96207
# [274]	eval-auc:0.951464	train-auc:0.962082
# [275]	eval-auc:0.951498	train-auc:0.962134
# [276]	eval-auc:0.951485	train-auc:0.962148
# [277]	eval-auc:0.951571	train-auc:0.962234
# [278]	eval-auc:0.951531	train-auc:0.962322
# [279]	eval-auc:0.95149	train-auc:0.962442
# [280]	eval-auc:0.951601	train-auc:0.962595
# [281]	eval-auc:0.951537	train-auc:0.962672
# [282]	eval-auc:0.95157	train-auc:0.962777
# [283]	eval-auc:0.951543	train-auc:0.962806
# [284]	eval-auc:0.951568	train-auc:0.962869
# [285]	eval-auc:0.951574	train-auc:0.962987
# [286]	eval-auc:0.951554	train-auc:0.963056
# [287]	eval-auc:0.951547	train-auc:0.963148
# [288]	eval-auc:0.951599	train-auc:0.963224
# [289]	eval-auc:0.951684	train-auc:0.963371
# [290]	eval-auc:0.951626	train-auc:0.963452
# [291]	eval-auc:0.951765	train-auc:0.963609
# [292]	eval-auc:0.951774	train-auc:0.96363
# [293]	eval-auc:0.951747	train-auc:0.963729
# [294]	eval-auc:0.951766	train-auc:0.963757
# [295]	eval-auc:0.95176	train-auc:0.963791
# [296]	eval-auc:0.9518	train-auc:0.963865
# [297]	eval-auc:0.951871	train-auc:0.963961
# [298]	eval-auc:0.95188	train-auc:0.963988
# [299]	eval-auc:0.951871	train-auc:0.964064
# [300]	eval-auc:0.951889	train-auc:0.964113
# [301]	eval-auc:0.951894	train-auc:0.964229
# [302]	eval-auc:0.951972	train-auc:0.964364
# [303]	eval-auc:0.952022	train-auc:0.964419
# [304]	eval-auc:0.952054	train-auc:0.964469
# [305]	eval-auc:0.952018	train-auc:0.964513
# [306]	eval-auc:0.952116	train-auc:0.964635
# [307]	eval-auc:0.952117	train-auc:0.964651
# [308]	eval-auc:0.952147	train-auc:0.964717
# [309]	eval-auc:0.95214	train-auc:0.964775
# [310]	eval-auc:0.952148	train-auc:0.964815
# [311]	eval-auc:0.952196	train-auc:0.96488
# [312]	eval-auc:0.95222	train-auc:0.964938
# [313]	eval-auc:0.952213	train-auc:0.96498
# [314]	eval-auc:0.95223	train-auc:0.964999
# [315]	eval-auc:0.952356	train-auc:0.965075
# [316]	eval-auc:0.952347	train-auc:0.965084
# [317]	eval-auc:0.952759	train-auc:0.965304
# [318]	eval-auc:0.95273	train-auc:0.965375
# [319]	eval-auc:0.952739	train-auc:0.965427
# [320]	eval-auc:0.952743	train-auc:0.965442
# [321]	eval-auc:0.952771	train-auc:0.965515
# [322]	eval-auc:0.952782	train-auc:0.965564
# [323]	eval-auc:0.952815	train-auc:0.965629
# [324]	eval-auc:0.952863	train-auc:0.965708
# [325]	eval-auc:0.952814	train-auc:0.965735
# [326]	eval-auc:0.952883	train-auc:0.96583
# [327]	eval-auc:0.95289	train-auc:0.9659
# [328]	eval-auc:0.952908	train-auc:0.965924
# [329]	eval-auc:0.952864	train-auc:0.966048
# [330]	eval-auc:0.952906	train-auc:0.966127
# [331]	eval-auc:0.952871	train-auc:0.966177
# [332]	eval-auc:0.952852	train-auc:0.966265
# [333]	eval-auc:0.952902	train-auc:0.966285
# [334]	eval-auc:0.952884	train-auc:0.966298
# [335]	eval-auc:0.95291	train-auc:0.966395
# [336]	eval-auc:0.952908	train-auc:0.966506
# [337]	eval-auc:0.952943	train-auc:0.966569
# [338]	eval-auc:0.952968	train-auc:0.966639
# [339]	eval-auc:0.952965	train-auc:0.966691
# [340]	eval-auc:0.952968	train-auc:0.966754
# [341]	eval-auc:0.952999	train-auc:0.966795
# [342]	eval-auc:0.953008	train-auc:0.966887
# [343]	eval-auc:0.952993	train-auc:0.966961
# [344]	eval-auc:0.952969	train-auc:0.967061
# [345]	eval-auc:0.952971	train-auc:0.967091
# [346]	eval-auc:0.95297	train-auc:0.967127
# [347]	eval-auc:0.95299	train-auc:0.967191
# [348]	eval-auc:0.953037	train-auc:0.967245
# [349]	eval-auc:0.953029	train-auc:0.967279
# [350]	eval-auc:0.953044	train-auc:0.967319
# [351]	eval-auc:0.953036	train-auc:0.967331
# [352]	eval-auc:0.953024	train-auc:0.967396
# [353]	eval-auc:0.953077	train-auc:0.967443
# [354]	eval-auc:0.953089	train-auc:0.967503
# [355]	eval-auc:0.953133	train-auc:0.967577
# [356]	eval-auc:0.953117	train-auc:0.967689
# [357]	eval-auc:0.953126	train-auc:0.967725
# [358]	eval-auc:0.953079	train-auc:0.967807
# [359]	eval-auc:0.953065	train-auc:0.967883
# [360]	eval-auc:0.953077	train-auc:0.967964
# [361]	eval-auc:0.953078	train-auc:0.968054
# [362]	eval-auc:0.953068	train-auc:0.968052
# [363]	eval-auc:0.953018	train-auc:0.968132
# [364]	eval-auc:0.95302	train-auc:0.968188
# [365]	eval-auc:0.953014	train-auc:0.968248
# [366]	eval-auc:0.953013	train-auc:0.968297
# [367]	eval-auc:0.953026	train-auc:0.968355
# [368]	eval-auc:0.953037	train-auc:0.9684
# [369]	eval-auc:0.952988	train-auc:0.968505
# [370]	eval-auc:0.95296	train-auc:0.968524
# [371]	eval-auc:0.952936	train-auc:0.968569
# [372]	eval-auc:0.953019	train-auc:0.968651
# [373]	eval-auc:0.952998	train-auc:0.968679
# [374]	eval-auc:0.953011	train-auc:0.96869
# [375]	eval-auc:0.953024	train-auc:0.968731
# [376]	eval-auc:0.953047	train-auc:0.968809
# [377]	eval-auc:0.953065	train-auc:0.968876
# [378]	eval-auc:0.953054	train-auc:0.968931
# [379]	eval-auc:0.953117	train-auc:0.969032
# [380]	eval-auc:0.95312	train-auc:0.969081
# [381]	eval-auc:0.953262	train-auc:0.969238
# [382]	eval-auc:0.953259	train-auc:0.969294
# [383]	eval-auc:0.953228	train-auc:0.969319
# [384]	eval-auc:0.953198	train-auc:0.9694
# [385]	eval-auc:0.953225	train-auc:0.969429
# [386]	eval-auc:0.953301	train-auc:0.969552
# [387]	eval-auc:0.95325	train-auc:0.969585
# [388]	eval-auc:0.953165	train-auc:0.969644
# [389]	eval-auc:0.953188	train-auc:0.969689
# [390]	eval-auc:0.953208	train-auc:0.969778
# [391]	eval-auc:0.953237	train-auc:0.969806
# [392]	eval-auc:0.95324	train-auc:0.969896
# [393]	eval-auc:0.953243	train-auc:0.96994
# [394]	eval-auc:0.953275	train-auc:0.97
# [395]	eval-auc:0.953286	train-auc:0.970028
# [396]	eval-auc:0.953256	train-auc:0.97012
# [397]	eval-auc:0.953262	train-auc:0.970133
# [398]	eval-auc:0.953219	train-auc:0.970164
# [399]	eval-auc:0.95324	train-auc:0.970183
# [400]	eval-auc:0.953258	train-auc:0.970215
# [401]	eval-auc:0.953234	train-auc:0.970222
# [402]	eval-auc:0.953209	train-auc:0.9703
# [403]	eval-auc:0.95318	train-auc:0.970418
# [404]	eval-auc:0.953231	train-auc:0.970495
# [405]	eval-auc:0.953268	train-auc:0.970548
# [406]	eval-auc:0.953263	train-auc:0.97058
# [407]	eval-auc:0.95327	train-auc:0.970599
# [408]	eval-auc:0.953246	train-auc:0.970649
# [409]	eval-auc:0.953217	train-auc:0.970772
# [410]	eval-auc:0.953167	train-auc:0.970852
# [411]	eval-auc:0.953183	train-auc:0.970945
# [412]	eval-auc:0.95317	train-auc:0.97096
# [413]	eval-auc:0.9532	train-auc:0.970998
# [414]	eval-auc:0.953163	train-auc:0.971015
# [415]	eval-auc:0.953173	train-auc:0.971097
# [416]	eval-auc:0.953198	train-auc:0.971134
# [417]	eval-auc:0.953256	train-auc:0.971163
# [418]	eval-auc:0.953287	train-auc:0.971223
# [419]	eval-auc:0.953279	train-auc:0.971232
# [420]	eval-auc:0.953234	train-auc:0.971256
# [421]	eval-auc:0.95323	train-auc:0.971281
# [422]	eval-auc:0.953206	train-auc:0.971323
# [423]	eval-auc:0.953223	train-auc:0.971373
# [424]	eval-auc:0.953228	train-auc:0.971418
# [425]	eval-auc:0.953275	train-auc:0.971467
# [426]	eval-auc:0.95329	train-auc:0.971473
# [427]	eval-auc:0.953322	train-auc:0.971512
# [428]	eval-auc:0.953283	train-auc:0.971545
# [429]	eval-auc:0.953271	train-auc:0.971567
# [430]	eval-auc:0.953248	train-auc:0.971593
# [431]	eval-auc:0.953257	train-auc:0.97162
# [432]	eval-auc:0.95323	train-auc:0.971648
# [433]	eval-auc:0.953253	train-auc:0.971689
# [434]	eval-auc:0.953242	train-auc:0.971743
# [435]	eval-auc:0.953271	train-auc:0.97178
# [436]	eval-auc:0.953514	train-auc:0.971908
# [437]	eval-auc:0.953468	train-auc:0.971953
# [438]	eval-auc:0.953499	train-auc:0.971967
# [439]	eval-auc:0.95367	train-auc:0.972069
# [440]	eval-auc:0.953664	train-auc:0.97212
# [441]	eval-auc:0.953637	train-auc:0.972147
# [442]	eval-auc:0.953622	train-auc:0.972158
# [443]	eval-auc:0.953697	train-auc:0.972267
# [444]	eval-auc:0.953689	train-auc:0.972303
# [445]	eval-auc:0.953824	train-auc:0.972451
# [446]	eval-auc:0.953891	train-auc:0.972536
# [447]	eval-auc:0.95388	train-auc:0.972547
# [448]	eval-auc:0.95387	train-auc:0.97257
# [449]	eval-auc:0.953877	train-auc:0.972613
# [450]	eval-auc:0.953836	train-auc:0.972654
# [451]	eval-auc:0.953842	train-auc:0.972693
# [452]	eval-auc:0.95387	train-auc:0.972733
# [453]	eval-auc:0.95388	train-auc:0.972788
# [454]	eval-auc:0.953859	train-auc:0.972817
# [455]	eval-auc:0.953833	train-auc:0.972893
# [456]	eval-auc:0.953836	train-auc:0.972943
# [457]	eval-auc:0.953832	train-auc:0.973009
# [458]	eval-auc:0.953799	train-auc:0.973048
# [459]	eval-auc:0.953821	train-auc:0.973085
# [460]	eval-auc:0.953876	train-auc:0.973123
# [461]	eval-auc:0.953873	train-auc:0.973172
# [462]	eval-auc:0.953886	train-auc:0.973179
# [463]	eval-auc:0.953901	train-auc:0.973225
# [464]	eval-auc:0.953937	train-auc:0.973251
# [465]	eval-auc:0.953905	train-auc:0.973267
# [466]	eval-auc:0.953879	train-auc:0.973279
# [467]	eval-auc:0.953923	train-auc:0.973341
# [468]	eval-auc:0.953873	train-auc:0.973387
# [469]	eval-auc:0.953854	train-auc:0.973405
# [470]	eval-auc:0.953817	train-auc:0.973441
# [471]	eval-auc:0.953758	train-auc:0.973493
# [472]	eval-auc:0.953774	train-auc:0.973497
# [473]	eval-auc:0.953796	train-auc:0.973557
# [474]	eval-auc:0.953788	train-auc:0.973559
# [475]	eval-auc:0.953802	train-auc:0.973579
# [476]	eval-auc:0.953927	train-auc:0.973647
# [477]	eval-auc:0.953895	train-auc:0.973666
# [478]	eval-auc:0.953948	train-auc:0.9737
# [479]	eval-auc:0.953935	train-auc:0.973746
# [480]	eval-auc:0.953949	train-auc:0.973779
# [481]	eval-auc:0.953934	train-auc:0.973822
# [482]	eval-auc:0.953895	train-auc:0.973859
# [483]	eval-auc:0.953868	train-auc:0.973882
# [484]	eval-auc:0.953865	train-auc:0.973925
# [485]	eval-auc:0.95382	train-auc:0.973957
# [486]	eval-auc:0.953825	train-auc:0.974
# [487]	eval-auc:0.953817	train-auc:0.974037
# [488]	eval-auc:0.953792	train-auc:0.974051
# [489]	eval-auc:0.953804	train-auc:0.974057
# [490]	eval-auc:0.953777	train-auc:0.974082
# [491]	eval-auc:0.95378	train-auc:0.974112
# [492]	eval-auc:0.953785	train-auc:0.974132
# [493]	eval-auc:0.953779	train-auc:0.974188
# [494]	eval-auc:0.953775	train-auc:0.974226
# [495]	eval-auc:0.9538	train-auc:0.974269
# [496]	eval-auc:0.953827	train-auc:0.974335
# [497]	eval-auc:0.953818	train-auc:0.974344
# [498]	eval-auc:0.953797	train-auc:0.974365
# [499]	eval-auc:0.953797	train-auc:0.974434
# [500]	eval-auc:0.953762	train-auc:0.974462
# [501]	eval-auc:0.95375	train-auc:0.974492
# [502]	eval-auc:0.953747	train-auc:0.974508
# [503]	eval-auc:0.953757	train-auc:0.974542
# [504]	eval-auc:0.953764	train-auc:0.974557
# [505]	eval-auc:0.953802	train-auc:0.974614
# [506]	eval-auc:0.953838	train-auc:0.974641
# [507]	eval-auc:0.953834	train-auc:0.974702
# [508]	eval-auc:0.953818	train-auc:0.974734
# [509]	eval-auc:0.953831	train-auc:0.974797
# [510]	eval-auc:0.953798	train-auc:0.974832
# [511]	eval-auc:0.953794	train-auc:0.974839
# [512]	eval-auc:0.953836	train-auc:0.97486
# [513]	eval-auc:0.953823	train-auc:0.974908
# [514]	eval-auc:0.953805	train-auc:0.974921
# [515]	eval-auc:0.953817	train-auc:0.975011
# [516]	eval-auc:0.953831	train-auc:0.975043
# [517]	eval-auc:0.953796	train-auc:0.975073
# [518]	eval-auc:0.953759	train-auc:0.975103
# [519]	eval-auc:0.953833	train-auc:0.975173
# [520]	eval-auc:0.953834	train-auc:0.975223
# [521]	eval-auc:0.953939	train-auc:0.975237
# [522]	eval-auc:0.953916	train-auc:0.975272
# [523]	eval-auc:0.953911	train-auc:0.975287
# [524]	eval-auc:0.953905	train-auc:0.975286
# [525]	eval-auc:0.953895	train-auc:0.975325
# [526]	eval-auc:0.953872	train-auc:0.97536
# [527]	eval-auc:0.953847	train-auc:0.975376
# [528]	eval-auc:0.953807	train-auc:0.975392
# [529]	eval-auc:0.953794	train-auc:0.975442
# [530]	eval-auc:0.953772	train-auc:0.975533
# [531]	eval-auc:0.953768	train-auc:0.975538
# [532]	eval-auc:0.953771	train-auc:0.975556
# [533]	eval-auc:0.953778	train-auc:0.975595
# [534]	eval-auc:0.953771	train-auc:0.975603
# [535]	eval-auc:0.953812	train-auc:0.975673
# [536]	eval-auc:0.953816	train-auc:0.97568
# [537]	eval-auc:0.953838	train-auc:0.975715
# [538]	eval-auc:0.953823	train-auc:0.975756
# [539]	eval-auc:0.953824	train-auc:0.975768
# [540]	eval-auc:0.953844	train-auc:0.975819
# [541]	eval-auc:0.953847	train-auc:0.975844
# [542]	eval-auc:0.953833	train-auc:0.975872
# [543]	eval-auc:0.953797	train-auc:0.975896
# [544]	eval-auc:0.953811	train-auc:0.975927
# [545]	eval-auc:0.95383	train-auc:0.97596
# [546]	eval-auc:0.95384	train-auc:0.976002
# [547]	eval-auc:0.953808	train-auc:0.976052
# [548]	eval-auc:0.95378	train-auc:0.976112
# [549]	eval-auc:0.95377	train-auc:0.976135
# [550]	eval-auc:0.953737	train-auc:0.97616
# [551]	eval-auc:0.95373	train-auc:0.97618
# [552]	eval-auc:0.953743	train-auc:0.976234
# [553]	eval-auc:0.953752	train-auc:0.976245
# [554]	eval-auc:0.953735	train-auc:0.9763
# [555]	eval-auc:0.953784	train-auc:0.976355
# [556]	eval-auc:0.95376	train-auc:0.976365
# [557]	eval-auc:0.953798	train-auc:0.976429
# [558]	eval-auc:0.95377	train-auc:0.976476
# [559]	eval-auc:0.953796	train-auc:0.976498
# [560]	eval-auc:0.953752	train-auc:0.976529
# [561]	eval-auc:0.953741	train-auc:0.976564
# [562]	eval-auc:0.953742	train-auc:0.976563
# [563]	eval-auc:0.953733	train-auc:0.976576
# [564]	eval-auc:0.953739	train-auc:0.976619
# [565]	eval-auc:0.953728	train-auc:0.976647
# [566]	eval-auc:0.95374	train-auc:0.976671
# [567]	eval-auc:0.95375	train-auc:0.976721
# [568]	eval-auc:0.95373	train-auc:0.976747
# [569]	eval-auc:0.953703	train-auc:0.976822
# [570]	eval-auc:0.953686	train-auc:0.976837
# [571]	eval-auc:0.953635	train-auc:0.97688
# [572]	eval-auc:0.953628	train-auc:0.976892
# [573]	eval-auc:0.953603	train-auc:0.976929
# [574]	eval-auc:0.953591	train-auc:0.976955
# [575]	eval-auc:0.953565	train-auc:0.976971
# [576]	eval-auc:0.953596	train-auc:0.977006
# [577]	eval-auc:0.953559	train-auc:0.977043
# [578]	eval-auc:0.953518	train-auc:0.977078
# [579]	eval-auc:0.953514	train-auc:0.977138
# [580]	eval-auc:0.953505	train-auc:0.977145
# [581]	eval-auc:0.953483	train-auc:0.977189
# [582]	eval-auc:0.953478	train-auc:0.977199
# [583]	eval-auc:0.95347	train-auc:0.977206
# [584]	eval-auc:0.953409	train-auc:0.977248
# [585]	eval-auc:0.953408	train-auc:0.977291
# [586]	eval-auc:0.953398	train-auc:0.977317
# [587]	eval-auc:0.953358	train-auc:0.977393
# [588]	eval-auc:0.95334	train-auc:0.977408
# [589]	eval-auc:0.953346	train-auc:0.977448
# [590]	eval-auc:0.953385	train-auc:0.977472
# [591]	eval-auc:0.953398	train-auc:0.977503
# [592]	eval-auc:0.953386	train-auc:0.97753
# [593]	eval-auc:0.953374	train-auc:0.977566
# [594]	eval-auc:0.953362	train-auc:0.977577
# [595]	eval-auc:0.953312	train-auc:0.977625
# [596]	eval-auc:0.95336	train-auc:0.977647
# [597]	eval-auc:0.953364	train-auc:0.977655
# [598]	eval-auc:0.953397	train-auc:0.977659
# [599]	eval-auc:0.953408	train-auc:0.977693
# [600]	eval-auc:0.953408	train-auc:0.977734
# [601]	eval-auc:0.953401	train-auc:0.977797
# [602]	eval-auc:0.95343	train-auc:0.977845
# [603]	eval-auc:0.953427	train-auc:0.97788
# [604]	eval-auc:0.953417	train-auc:0.977925
# [605]	eval-auc:0.953379	train-auc:0.977953
# [606]	eval-auc:0.953358	train-auc:0.977975
# [607]	eval-auc:0.953364	train-auc:0.978004
# [608]	eval-auc:0.953383	train-auc:0.978036
# [609]	eval-auc:0.953334	train-auc:0.978087
# [610]	eval-auc:0.953317	train-auc:0.978144
# [611]	eval-auc:0.953307	train-auc:0.978212
# [612]	eval-auc:0.953418	train-auc:0.978235
# [613]	eval-auc:0.953438	train-auc:0.978247
# [614]	eval-auc:0.95345	train-auc:0.978293
# [615]	eval-auc:0.953428	train-auc:0.978313
# [616]	eval-auc:0.953404	train-auc:0.978348
# [617]	eval-auc:0.953416	train-auc:0.978376
# [618]	eval-auc:0.953451	train-auc:0.978427
# [619]	eval-auc:0.953398	train-auc:0.978455
# [620]	eval-auc:0.953412	train-auc:0.978475
# [621]	eval-auc:0.953418	train-auc:0.9785
# [622]	eval-auc:0.953415	train-auc:0.978552
# [623]	eval-auc:0.953422	train-auc:0.978577
# [624]	eval-auc:0.953407	train-auc:0.978621
# [625]	eval-auc:0.953462	train-auc:0.978668
# [626]	eval-auc:0.953445	train-auc:0.978697
# [627]	eval-auc:0.953488	train-auc:0.978684
# [628]	eval-auc:0.953484	train-auc:0.97872
# [629]	eval-auc:0.953497	train-auc:0.978729
# [630]	eval-auc:0.953503	train-auc:0.978754
# [631]	eval-auc:0.953538	train-auc:0.978776
# [632]	eval-auc:0.953555	train-auc:0.978815
# [633]	eval-auc:0.953536	train-auc:0.978868
# [634]	eval-auc:0.953527	train-auc:0.978888
# [635]	eval-auc:0.953489	train-auc:0.978921
# [636]	eval-auc:0.953478	train-auc:0.978923
# [637]	eval-auc:0.953462	train-auc:0.978955
# [638]	eval-auc:0.953428	train-auc:0.978997
# [639]	eval-auc:0.953433	train-auc:0.979038
# [640]	eval-auc:0.953429	train-auc:0.979088
# [641]	eval-auc:0.953404	train-auc:0.979123
# [642]	eval-auc:0.953402	train-auc:0.979136
# [643]	eval-auc:0.953381	train-auc:0.979151
# [644]	eval-auc:0.953367	train-auc:0.979183
# [645]	eval-auc:0.953383	train-auc:0.979211
# [646]	eval-auc:0.953471	train-auc:0.979245
# [647]	eval-auc:0.953463	train-auc:0.979277
# [648]	eval-auc:0.953466	train-auc:0.979292
# [649]	eval-auc:0.953477	train-auc:0.979305
# [650]	eval-auc:0.953488	train-auc:0.979332
# [651]	eval-auc:0.953481	train-auc:0.979352
# [652]	eval-auc:0.953504	train-auc:0.979364
# [653]	eval-auc:0.953504	train-auc:0.979395
# [654]	eval-auc:0.953531	train-auc:0.979399
# [655]	eval-auc:0.953524	train-auc:0.979456
# [656]	eval-auc:0.953524	train-auc:0.979468
# [657]	eval-auc:0.953481	train-auc:0.979493
# [658]	eval-auc:0.953365	train-auc:0.979542
# [659]	eval-auc:0.953329	train-auc:0.979557
# [660]	eval-auc:0.953367	train-auc:0.979606
# [661]	eval-auc:0.953392	train-auc:0.97965
# [662]	eval-auc:0.953417	train-auc:0.979675
# [663]	eval-auc:0.953425	train-auc:0.979702
# [664]	eval-auc:0.953424	train-auc:0.979736
# [665]	eval-auc:0.953413	train-auc:0.979748
# [666]	eval-auc:0.953463	train-auc:0.979784
# [667]	eval-auc:0.953538	train-auc:0.979827
# [668]	eval-auc:0.953491	train-auc:0.979855
# [669]	eval-auc:0.953508	train-auc:0.979888
# [670]	eval-auc:0.953469	train-auc:0.979929
# [671]	eval-auc:0.953443	train-auc:0.979964
# [672]	eval-auc:0.953447	train-auc:0.979977
# [673]	eval-auc:0.953438	train-auc:0.980006
# [674]	eval-auc:0.953494	train-auc:0.980032
# [675]	eval-auc:0.953479	train-auc:0.980048
# [676]	eval-auc:0.953461	train-auc:0.980063
# [677]	eval-auc:0.953466	train-auc:0.980086
# [678]	eval-auc:0.953454	train-auc:0.98011
# [679]	eval-auc:0.953446	train-auc:0.980148
# [680]	eval-auc:0.953488	train-auc:0.980185
# [681]	eval-auc:0.95349	train-auc:0.980236
# [682]	eval-auc:0.953462	train-auc:0.980258
# [683]	eval-auc:0.953428	train-auc:0.980301
# [684]	eval-auc:0.953429	train-auc:0.980326
# [685]	eval-auc:0.953473	train-auc:0.980359
# [686]	eval-auc:0.953397	train-auc:0.980394
# [687]	eval-auc:0.953394	train-auc:0.980403
# [688]	eval-auc:0.953399	train-auc:0.980411
# [689]	eval-auc:0.953394	train-auc:0.980465
# [690]	eval-auc:0.953361	train-auc:0.980499
# [691]	eval-auc:0.953321	train-auc:0.98052
# [692]	eval-auc:0.953228	train-auc:0.980571
# [693]	eval-auc:0.95322	train-auc:0.980598
# [694]	eval-auc:0.953207	train-auc:0.980604
# [695]	eval-auc:0.9532	train-auc:0.980644
# [696]	eval-auc:0.953196	train-auc:0.980667
# [697]	eval-auc:0.953188	train-auc:0.980696
# [698]	eval-auc:0.953192	train-auc:0.980711
# [699]	eval-auc:0.953193	train-auc:0.980723
# [700]	eval-auc:0.953166	train-auc:0.980766
# [701]	eval-auc:0.953157	train-auc:0.980806
# [702]	eval-auc:0.953156	train-auc:0.980838
# [703]	eval-auc:0.953141	train-auc:0.980881
# [704]	eval-auc:0.95312	train-auc:0.980904
# [705]	eval-auc:0.953111	train-auc:0.980909
# [706]	eval-auc:0.953118	train-auc:0.980932
# [707]	eval-auc:0.953148	train-auc:0.980968
# [708]	eval-auc:0.953134	train-auc:0.981001
# [709]	eval-auc:0.953173	train-auc:0.981032
# [710]	eval-auc:0.953165	train-auc:0.981047
# [711]	eval-auc:0.953192	train-auc:0.981062
# [712]	eval-auc:0.953159	train-auc:0.981082
# [713]	eval-auc:0.953154	train-auc:0.981089
# [714]	eval-auc:0.953175	train-auc:0.981104
# [715]	eval-auc:0.95317	train-auc:0.981111
# [716]	eval-auc:0.953184	train-auc:0.981125
# [717]	eval-auc:0.953174	train-auc:0.981176
# [718]	eval-auc:0.953183	train-auc:0.98119
# [719]	eval-auc:0.953194	train-auc:0.981226

# %%
dtrain = xgb.DMatrix(train_data,label=train_label)
# dval = xgb.DMatrix(x_val,label=y_val)
param = {'learning_rate' : 0.1,
        'n_estimators': 1000,
        'max_depth': 4,
        'min_child_weight': 7,
        'gamma': 0.9,
        'subsample': 0.94,
        'colsample_bytree': 0.75,
        'eta': 0.05,
        'silent': 1,
        'objective':
        'binary:logistic',
        'scale_pos_weight':1}

num_round = 1000
plst = list(param.items())
plst += [('eval_metric', 'auc')]
evallist = [(dtrain, 'train')]
bst=xgb.train(plst,dtrain,num_round,evallist,early_stopping_rounds=100)
dtest = xgb.DMatrix(test_data)
y = bst.predict(dtest)
# Out:
# [0]	train-auc:0.76467
# Will train until train-auc hasn't improved in 100 rounds.
# [1]	train-auc:0.818515
# [2]	train-auc:0.822543
# [3]	train-auc:0.824663
# [4]	train-auc:0.83195
# [5]	train-auc:0.840617
# [6]	train-auc:0.847946
# [7]	train-auc:0.848859
# [8]	train-auc:0.858868
# [9]	train-auc:0.860146
# [10]	train-auc:0.864873
# [11]	train-auc:0.8643
# [12]	train-auc:0.870293
# [13]	train-auc:0.871633
# [14]	train-auc:0.870347
# [15]	train-auc:0.871358
# [16]	train-auc:0.876579
# [942]	train-auc:0.982747
# [943]	train-auc:0.982765
# [944]	train-auc:0.982776
# [945]	train-auc:0.982802
# [946]	train-auc:0.982813
# [947]	train-auc:0.982822
# [948]	train-auc:0.982847
# [949]	train-auc:0.982873
# [950]	train-auc:0.98289
# [951]	train-auc:0.982898
# [952]	train-auc:0.982909
# [953]	train-auc:0.982911
# [954]	train-auc:0.98293
# [955]	train-auc:0.98297
# [956]	train-auc:0.983011
# [957]	train-auc:0.983032
# [958]	train-auc:0.98304
# [959]	train-auc:0.983052
# [960]	train-auc:0.983062
# [961]	train-auc:0.983075
# [962]	train-auc:0.983106
# [963]	train-auc:0.983124
# [964]	train-auc:0.983138
# [965]	train-auc:0.983151
# [966]	train-auc:0.983156
# [967]	train-auc:0.983178
# [968]	train-auc:0.983199
# [969]	train-auc:0.983216
# [970]	train-auc:0.983235
# [971]	train-auc:0.98327
# [972]	train-auc:0.983281
# [973]	train-auc:0.983307
# [974]	train-auc:0.983326
# [975]	train-auc:0.983355
# [976]	train-auc:0.983373
# [977]	train-auc:0.983389
# [978]	train-auc:0.983402
# [979]	train-auc:0.98343
# [980]	train-auc:0.983439
# [981]	train-auc:0.983451
# [982]	train-auc:0.983463
# [983]	train-auc:0.983467
# [984]	train-auc:0.983469
# [985]	train-auc:0.983476
# [986]	train-auc:0.983494
# [987]	train-auc:0.983502
# [988]	train-auc:0.983518
# [989]	train-auc:0.983538
# [990]	train-auc:0.983558
# [991]	train-auc:0.983579
# [992]	train-auc:0.983595
# [993]	train-auc:0.983593
# [994]	train-auc:0.983621
# [995]	train-auc:0.983621
# [996]	train-auc:0.983637
# [997]	train-auc:0.983654
# [998]	train-auc:0.983666
# [999]	train-auc:0.983685

# %%
mysubmit = order_test
mysubmit['orderType'] = y
mysubmit.to_csv('submit/xgboost14.csv',index=False)

# %%
bst.get_fscore()
# Out:
# {'actionType_1': 357,
#  'actionType_2': 137,
#  'actionType_3': 115,
#  'actionType_4': 124,
#  'actionType_5': 380,
#  'actionType_6': 390,
#  'actionType_7': 131,
#  'actionType_8': 134,
#  'actionType_9': 92,
#  'age': 63,
#  'buy_flags': 17,
#  'city': 230,
#  'continent': 73,
#  'count': 211,
#  'flag_five': 57,
#  'flag_seven': 4,
#  'flag_six': 93,
#  'gender': 61,
#  'last_5dis': 660,
#  'last_6dis': 652,
#  'last_7dis': 187,
#  'last_8dis': 230,
#  'last_9dis': 92,
#  'last_two_day': 74,
#  'last_two_second': 521,
#  'last_type': 243,
#  'orderHistory_feat_sum': 65,
#  'province': 178,
#  'rating': 80,
#  'three_type': 217,
#  'two_three_day': 71,
#  'two_three_second': 698,
#  'two_type': 174,
#  'userid': 666}

# %%
temp = ac[ac.userid == 100000000637]

# %%
order[order_his.userid == 100000000637]

# %%
temp.head()

# %%
temp.loc[1121, 'actionType']

# %%
comment.head()
# Out:
#          userid  orderid  rating                   tags     commentsKeyWords
# 0  100000000013  1000015     4.0                    NaN  ['很','简陋','太','随便']
# 1  100000000231  1000024     5.0              提前联系|耐心等候           ['很','细心']
# 2  100000000471  1000038     5.0                    NaN                  NaN
# 3  100000000637  1000040     5.0  主动热情|提前联系|举牌迎接|主动搬运行李                  NaN
# 4  100000000755  1000045     1.0                  未举牌服务                  NaN

# %%
order_his[order_his.orderid == 1000045]
# Out:
# Empty DataFrame
# Columns: [userid, orderid, orderTime, orderType, city, country, continent]
# Index: []

# %%
order[order.orderType == 1]
# Out:
#              userid  orderType
# 10     100000000637          1
# 11     100000000695          1
# 14     100000000867          1
# 16     100000000975          1
# 17     100000001023          1
# 22     100000001505          1
# 32     100000002199          1
# 33     100000002215          1
# 46     100000003091          1
# 49     100000003461          1
# 52     100000003611          1
# 62     100000004297          1
# 71     100000005007          1
# 75     100000005649          1
# 77     100000005739          1
# 87     100000006539          1
# 89     100000006605          1
# 104    100000007745          1
# 107    100000008119          1
# 109    100000008425          1
# 115    100000009017          1
# 116    100000009249          1
# 119    100000009481          1
# 120    100000009491          1
# 125    100000009773          1
# 127    100000009925          1
# 128    100000010101          1
# 131    100000010199          1
# 149    100000011845          1
# 168    100000012867          1
# ...             ...        ...
# 40130  114862767040          1
# 40139  114862969140          1
# 40149  114864169646          1
# 40159  114864367449          1
# 40162  114864467347          1
# 40169  114864667143          1
# 40171  114864667440          1
# 40189  114865153947          1
# 40191  114865167546          1
# 40197  114865267049          1
# 40200  114865267842          1
# 40201  114865267940          1
# 40207  114865367843          1
# 40211  114865453949          1
# 40212  114865467046          1
# 40221  114865653740          1
# 40225  114865667845          1
# 40246  114868267642          1
# 40250  114868367541          1
# 40253  114868467442          1
# 40254  114868467547          1
# 40256  114868567347          1
# 40257  114868567441          1
# 40275  114869067447          1
# 40277  114869267343          1
# 40278  114869267443          1
# 40283  114869567242          1
# 40291  114869867143          1
# 40292  114869867443          1
# 40302  114999280232          1
#
# [6625 rows x 2 columns]

# %%
# rank

test = pd.read_csv('submit/xgboost8.csv')
test.head()
# Out:
#          userid  orderType
# 0  100000000371   0.075764
# 1  100000001215   0.003399
# 2  100000001445   0.011033
# 3  100000001575   0.998092
# 4  100000001601   0.000687

# %%
m = np.array(test.sort_values(by='orderType').index)

# %%
len(m)
# Out:
# 10076

# %%
test['rank'] = m

# %%
test.head()
# Out:
#          userid  orderType  rank
# 0  100000000371   0.075764  7665
# 1  100000001215   0.003399  5854
# 2  100000001445   0.011033  8279
# 3  100000001575   0.998092  7592
# 4  100000001601   0.000687  6938

# %%
test['new'] = test['rank'] / 10075
test.head()
# Out:
#          userid  orderType  rank       new
# 0  100000000371   0.075764  7665  0.760794
# 1  100000001215   0.003399  5854  0.581042
# 2  100000001445   0.011033  8279  0.821737
# 3  100000001575   0.998092  7592  0.753548
# 4  100000001601   0.000687  6938  0.688635

# %%
del test['orderType']
del test['rank']

# %%
test.head()
# Out:
#          userid       new
# 0  100000000371  0.760794
# 1  100000001215  0.581042
# 2  100000001445  0.821737
# 3  100000001575  0.753548
# 4  100000001601  0.688635

# %%
test.rename(columns={'new':'orderType'}, inplace = True)
test.to_csv('submit/xg8-rank.csv', index=False)
